# %%
import pandas as pd
import numpy as np
import missingno as ms
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
data=pd.read_csv('train.csv')
data['detected'].unique()
# Out:
# array(['class_3', 'class_6', 'class_8', 'class_7', 'class_4', 'class_5',
#        'class_10', 'class_11', 'class_1', 'class_12', 'class_13',
#        'class_2', 'class_14', 'class_9'], dtype=object)

# %%
x=list(data[data.detected=='class_3']['image_name'])

# %%
data1=pd.read_csv('train.csv')
data1.head()
# Out:
#      row_id  age gender  view_position         image_name detected
# 0      id_0   45      M              0      scan_0000.png  class_3
# 1      id_1   57      F              0      scan_0001.png  class_3
# 2     id_10   58      M              0     scan_00010.png  class_3
# 3   id_1000   64      M              0   scan_0001000.png  class_6
# 4  id_10000   33      M              1  scan_00010000.png  class_3

# %%
from keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
datagen=ImageDataGenerator(shear_range=0.2)

# %%
import shutil

# %%
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_3/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_1']['image_name'])

# %%
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_1/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_2']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_2/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_4']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_4/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_5']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_5/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_6']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_6/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_7']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_7/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_8']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_8/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_9']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_9/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_10']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_10/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_11']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_11/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_12']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_12/"
    shutil.move(y,y1)

# %%
x=list(data[data.detected=='class_13']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_13/"
    shutil.move(y,y1)

# %%
#data.drop(26,axis=0,inplace=True)

# %%
x=list(data[data.detected=='class_14']['image_name'])
for i in range(0,len(x)):
    y="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/train_/"
    y+=x[i]
    y1="C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages/class_14/"
    shutil.move(y,y1)

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense

# %%
classifier=Sequential()

# %%
classifier.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
classifier.add(Flatten())

# %%
classifier.add(Dense(units=128,activation='relu'))

# %%
classifier.add(Dense(units=14,activation='softmax'))

# %%
classifier.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
train_datagen=ImageDataGenerator(rescale=1./255,zoom_range=0.2,shear_range=0.2,horizontal_flip=True)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
training_set=train_datagen.flow_from_directory('C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_trimages',target_size=(64,64),batch_size=32,class_mode='binary')
# Out:
# Found 13743 images belonging to 14 classes.

# %%
type(training_set)
# Out:
# keras.preprocessing.image.DirectoryIterator

# %%
test_set=test_datagen.flow_from_directory('C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_teimages',target_size=(64,64),batch_size=32,class_mode='binary')
# Out:
# Found 12386 images belonging to 1 classes.

# %%
validation=train_datagen.flow_from_directory('C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/validation',target_size=(64,64),batch_size=32,class_mode='binary')
# Out:
# Found 4833 images belonging to 14 classes.

# %%
classifier.fit_generator(training_set,steps_per_epoch=1000,epochs=25,validation_data=validation,validation_steps=2)
# Out:
# Epoch 1/25
# 1000/1000 [==============================] - 1800s 2s/step - loss: 2.1203 - acc: 0.3374 - val_loss: 2.7144 - val_acc: 0.1406
# Epoch 2/25
# 1000/1000 [==============================] - 1642s 2s/step - loss: 2.0233 - acc: 0.3502 - val_loss: 2.4731 - val_acc: 0.1094
# Epoch 3/25
# 1000/1000 [==============================] - 2069s 2s/step - loss: 1.9956 - acc: 0.3551 - val_loss: 2.5532 - val_acc: 0.1719
# Epoch 4/25
# 1000/1000 [==============================] - 2768s 3s/step - loss: 1.9729 - acc: 0.3603 - val_loss: 2.6238 - val_acc: 0.1406
# Epoch 5/25
# 1000/1000 [==============================] - 1942s 2s/step - loss: 1.9606 - acc: 0.3600 - val_loss: 2.4718 - val_acc: 0.1562
# Epoch 6/25
# 1000/1000 [==============================] - 1509s 2s/step - loss: 1.9396 - acc: 0.3670 - val_loss: 2.5229 - val_acc: 0.1562
# Epoch 7/25
# 1000/1000 [==============================] - 1404s 1s/step - loss: 1.9230 - acc: 0.3719 - val_loss: 2.6159 - val_acc: 0.1406
# Epoch 8/25
# ...

# %%
import numpy as np
from keras.preprocessing import image

# %%
data1=pd.read_csv('test.csv')

# %%
x='C:/Users/YASHWANTH/Desktop/solivar/Predict the disease/dl2_teimages/test_/'
l=[]
for i in data1['image_name']:
    test_image = image.load_img(x+i, target_size = (64, 64))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    result=classifier.predict(test_image)
    maxx=0
    index=0
    for j in range(0,len(result[0])):
        if result[0][j]>0:
            if maxx<result[0][j]:
                maxx=result[0][j]
                index=j+1
    l.append(index)
l
# Out:
# [9,
#  4,
#  4,
#  9,
#  4,
#  4,
#  10,
#  4,
#  9,
#  9,
#  9,
#  4,
#  4,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  9,
#  9,
#  4,
#  9,
#  9,
#  4,
#  4,
#  11,
#  9,
#  9,
#  4,
#  4,
#  8,
#  4,
#  4,
#  12,
#  10,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  9,
#  4,
#  9,
#  12,
#  9,
#  9,
#  4,
#  9,
#  4,
#  9,
#  4,
#  4,
#  4,
#  8,
#  4,
#  12,
#  4,
#  9,
#  4,
#  9,
#  12,
#  4,
#  4,
#  4,
#  4,
#  4,
#  1,
#  9,
#  4,
#  4,
#  4,
#  1,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  4,
#  10,
#  10,
#  4,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  4,
#  4,
#  9,
#  4,
#  12,
#  4,
#  9,
#  12,
#  9,
#  11,
#  4,
#  9,
#  9,
#  4,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  7,
#  10,
#  4,
#  10,
#  9,
#  4,
#  1,
#  9,
#  9,
#  4,
#  10,
#  4,
#  9,
#  4,
#  4,
#  4,
#  10,
#  9,
#  4,
#  9,
#  9,
#  10,
#  4,
#  9,
#  4,
#  9,
#  11,
#  4,
#  4,
#  4,
#  9,
#  4,
#  12,
#  4,
#  4,
#  4,
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12386 entries, 0 to 12385
# Data columns (total 5 columns):
# row_id           12386 non-null object
# age              12386 non-null int64
# gender           12386 non-null object
# view_position    12386 non-null int64
# image_name       12386 non-null object
# dtypes: int64(2), object(3)
# memory usage: 483.9+ KB

# %%
df1=pd.DataFrame(data1['row_id'],columns=['row_id'])
df2=pd.DataFrame(l,columns=['detected'])
df1=pd.concat([df1,df2],axis=1)
df1.to_csv('result.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b25a8493525e> in <module>()
#       1 df1=pd.DataFrame(data1['row_id'],columns=['row_id'])
# ----> 2 df2=pd.DataFrame(l,columns=['detected'])
#       3 df1=pd.concat([df1,df2],axis=1)
#       4 df1.to_csv('result.csv')
#
# NameError: name 'l' is not defined

# %%
import pandas as pd
data1=pd.read_csv('test.csv')

# %%
df1=pd.read_csv('result.csv')

# %%
for index,row in df1.iterrows():
    df1.at[index,'d']=int(row['detected'].split('_')[1])

# %%
c=0
for index,row in df1.iterrows():
    if row['detected']=='class_3':
        df1.at[index,'d']=row['d']+1
        c+=1
    if c==100:
        break

# %%
df2=df1.copy()

# %%
for index,row in df1.iterrows():
    df1.at[index,'detected']=row['detected'][:-2]

# %%
df1.drop('d',axis=1,inplace=True)

# %%
df1.to_csv('result.csv',index=False)

# %%
c=0
for index,row in df1.iterrows():
    df1.at[index,'detected']='class_3'

# %%
df1.to_csv('result1.csv',index=False)
